# %% [markdown]
# <a href="https://colab.research.google.com/github/House321/CSC_221_jbarr029/blob/main/Week1A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 13
b = 21.6
total = a + b
print(a, b, total)
# Out:
# 13 21.6 34.6

# %%
print("Type in your name: ")

name = input()

print(f"Hello, {name}")
# Out:
# Type in your name:
# Josue
# Hello, Josue

# %%
total = 0
n = 50
while n <= 700:
  total = total + n
  n = n + 1
  print(n, total)
print(total)
# Out:
# 51 50
# 52 101
# 53 153
# 54 206
# 55 260
# 56 315
# 57 371
# 58 428
# 59 486
# 60 545
# 61 605
# 62 666
# 63 728
# 64 791
# 65 855
# 66 920
# 67 986
# 68 1053
# 69 1121
# 70 1190
# 71 1260
# 72 1331
# 73 1403
# 74 1476
# 75 1550
# 76 1625
# 77 1701
# 78 1778
# 79 1856
# 80 1935
# 81 2015
# 82 2096
# 83 2178
# 84 2261
# 85 2345
# 86 2430
# 87 2516
# 88 2603
# 89 2691
# 90 2780
# 91 2870
# 92 2961
# 93 3053
# 94 3146
# 95 3240
# 96 3335
# 97 3431
# 98 3528
# 99 3626
# 100 3725
# 101 3825
# 102 3926
# 103 4028
# 104 4131
# 105 4235
# 106 4340
# 107 4446
# 108 4553
# 109 4661
# 110 4770
# 111 4880
# 112 4991
# 113 5103
# 114 5216
# 115 5330
# 116 5445
# 117 5561
# 118 5678
# 119 5796
# 120 5915
# 121 6035
# 122 6156
# 123 6278
# 124 6401
# 125 6525
# 126 6650
# 127 6776
# 128 6903
# 129 7031
# 130 7160
# 131 7290
# 132 7421
# 133 7553
# 134 7686
# 135 7820
# 136 7955
# 137 8091
# 138 8228
# 139 8366
# 140 8505
# 141 8645
# 142 8786
# 143 8928
# 144 9071
# 145 9215
# 146 9360
# 147 9506
# ...
